# %% [markdown]
# <a href="https://colab.research.google.com/github/Yhadiii26/nuevoRumores/blob/main/Clasificaci%C3%B3n_d_Rumores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df= pd.read_csv('dataset_train_val.csv')

# %%
df.head()
# Out:
#                                                 text  is_rumor    user.handle  \
# 0  @korikisulda listen. Hey are protesting agains...       0.0    vida_andras
# 1  “@TheEyeOfControl: Americans are 8 times more ...       1.0  SoulBrothaIII
# 2  @Israel @IsraelMFA #Itsallaboutisrael  (We kil...       0.0        mdp4202
# 3              @matwilson6 @capetownbrown Always do.       0.0  scottsmith349
# 4  @TomGauthey I'm out of date already of course,...       0.0       CMHarkey
#
#           topic
# 0  charliehebdo
# 1      ferguson
# 2           NaN
# 3      ferguson
# 4  charliehebdo

# %%
df.shape
# Out:
# (59322, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59322 entries, 0 to 59321
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         59322 non-null  object
#  1   is_rumor     59320 non-null  float64
#  2   user.handle  59320 non-null  object
#  3   topic        47196 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# text               0
# is_rumor           2
# user.handle        2
# topic          12126
# dtype: int64

# %%
df['is_rumor'].fillna(df['is_rumor'].median(),inplace=True)
# Out:
# /tmp/ipython-input-475948396.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['is_rumor'].fillna(df['is_rumor'].median(),inplace=True)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test,  y_train, y_test=train_test_split(df['text'],df['is_rumor'],test_size=0.25)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizador = CountVectorizer()
x_train_vec = vectorizador.fit_transform(x_train)
x_test_vec = vectorizador.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(x_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

predict = modelo.predict(x_test_vec)
accuracy = accuracy_score(y_test,predict)
print(accuracy)
# Out:
# 0.905535702245297

# %%
df_test = pd.read_csv('dataset_test_sin_etiqueta.csv')
df_test.head()
# Out:
#                                                 text   user.handle  \
# 0  @WSJ haven't we heard that about four times al...        L4rryC
# 1  @bopanc @FT @LukeReuters well, there goes any ...  freethink120
# 2  @iowahawkblog @RamziHabre You mean that wasn't...      kshaidle
# 3  @OmarWaraich @imsabbah #BreakingNews Correspon...     ShafeekTg
# 4  @_vaNessasary not the point I was trying to ma...      NBully18
#
#           topic  ID
# 0           NaN   1
# 1  charliehebdo   2
# 2  charliehebdo   3
# 3  charliehebdo   4
# 4      ferguson   5

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3123 entries, 0 to 3122
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   text         3123 non-null   object
#  1   user.handle  3123 non-null   object
#  2   topic        2472 non-null   object
#  3   ID           3123 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 97.7+ KB

# %%
df_test.isnull().sum()
# Out:
# text             0
# user.handle      0
# topic          651
# ID               0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer


nueva= df_test['text']
X_nueva = vectorizador.transform(nueva)
resultado= modelo.predict(X_nueva)

df_test['etiqueta']= resultado

df_test.head()
# Out:
#                                                 text   user.handle  \
# 0  @WSJ haven't we heard that about four times al...        L4rryC
# 1  @bopanc @FT @LukeReuters well, there goes any ...  freethink120
# 2  @iowahawkblog @RamziHabre You mean that wasn't...      kshaidle
# 3  @OmarWaraich @imsabbah #BreakingNews Correspon...     ShafeekTg
# 4  @_vaNessasary not the point I was trying to ma...      NBully18
#
#           topic  ID  etiqueta
# 0           NaN   1       0.0
# 1  charliehebdo   2       0.0
# 2  charliehebdo   3       0.0
# 3  charliehebdo   4       0.0
# 4      ferguson   5       1.0

# %%
output = pd.DataFrame({'ID': df_test['ID'], 'etiqueta': resultado})
output.to_csv('submission3.csv', index=False)
